# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'], 
    keyword_fields=['course'], 
    db_path='faq.db'
)

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI 
openai_client = OpenAI()

# %%
from rag_helper import RAGBase

assistant = RAGBase(llm_client=openai_client,index=sqlite_index)

# %%
assistant.rag("I just discovered the course. Can I still enroll?")
# Out:
# 'Yes, you can still join. If you want a certificate, though, you need to submit your project while submissions are still open.'
